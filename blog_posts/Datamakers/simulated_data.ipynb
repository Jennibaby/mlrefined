# %% [markdown]
# # Make your own toy supervised / unsupervised learning data sets
#
# This notebook shows you how to use tools for making toy datasets for regression, classification, dimension reduction / clustering  - by both random generation and visual point-and-click action.  These allow you to quickly make interesting datasets for testing machine learning algorithms.

# %%
# imports from custom library
import sys
sys.path.append('../../')
import matplotlib.pyplot as plt
from mlrefined_libraries import datamakers_library as datalib
import autograd.numpy as np
import math
import pandas as pd
# %matplotlib notebook

# this is needed to compensate for %matplotlib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1.  Make your own multiclass toy classification dataset with random linear or nonlinear boundaries!

# %% [markdown]
# The next few cells demonstrate how to use the **random_classification_datamakers.py** datamakers.  These generate random classification datasets with linear or nonlinear boundaries.

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 1: </span> Random linearly separable two-class classification datasets

# %% [markdown]
# The next cell imports the file and creates an instance of the datamaker.

# %%
# import datamaker file / # create an instance of the datamaker
demo1 = datalib.random_classification_datamakers.Random_Classification_Datamaker()

# %% [markdown]
# The following cells demonstrate some random linear classification datasets.
#
# For example, create a random two-class dataset.

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo1.make_linear_classification_dataset(num_pts = 200,num_seps = 1)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 2: </span> Random linearly separable multiclass classification datasets

# %% [markdown]
# To increase the number of boundaries simply adjust the 'num_seps' parameter.  To make a random multiclass dataset with two linear boundaries set num_seps = 2, as follows.

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo1.make_linear_classification_dataset(num_pts = 200,num_seps = 2)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# Or three linear boundaries...just set num_seps = 3.

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo1.make_linear_classification_dataset(num_pts = 200,num_seps = 3)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# If you don't like the look of it - just refresh the cell to get another random instance of whatever sort of dataset you want.
#
# If you finally like the look of a dataset activate the next cell to save it.  This will save both the dataset and the boundaries shown.

# %%
# save a dataset once you like the look of it
data_csvname = 'my_classification_data.csv'
seps_csvname = 'my_classification_separators.csv'
demo.save_data(data_csvname,seps_csvname)

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 3: </span> Random two-class nonlinear classification datasets

# %% [markdown]
# The same file allows you to make random nonlinear classification datasets as well.  For example, to make a two-class dataset...

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo.make_nonlinear_classification_dataset(num_pts = 200,num_seps = 1)

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 4: </span> Random multiclass nonlinear classification datasets

# %% [markdown]
# Ao add more sepsrators adjust the 'num_seps' variable.  For example to get a multiclass dataset with two nonlinear separators set num_seps = 2.

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo.make_nonlinear_classification_dataset(num_pts = 200,num_seps = 2)

# %% [markdown]
# etc.,  If you don't like the look of a dataset just rerun the cell to get another random instance.  Once you like the look of the dataset activate the next cell to save it.

# %%
# save a dataset once you like the look of it
data_csvname = 'my_classification_data.csv'
seps_csvname = 'my_classification_separators.csv'
demo.save_data(data_csvname,seps_csvname)

# %% [markdown]
# #### <span style="color:#a50e3e;">Example 5: </span> Make a randon two-class dataset separated by a circular boundary

# %% [markdown]
# If you just want a two-class dataset separated by a circle, use the next cell.

# %%
# generate data, labels, and true linear separators: num_pts = number of points in dataset, num_seps = number of separators
demo.make_circle_classification_dataset(num_pts = 200)

# %% [markdown]
# #  2. Make your own toy classification or clustering dataset by point and click action
#
# The next few cells show you how to use another simple tool for creating multiclass toy datasets by visual point-and-click action.
#
# Create an instance of the datamaker tool below, and an empty plot will appear.  Put points of one class wherever you like by clicking on the plotting area.  Once you are finished placing points from one class, click just outside of the square plotting area in the Figure to change classes, then place points from the next class - these should show in a different color than your previous class (maximum of 5 classes allowed).  And so on.  Once you have finished placing points call the 'save_data' function to save your data with labels.
#
# Note: this can be used to make datasets for both classification and clustering experiments.

# %%
# turn on interactive matplotlib
# %matplotlib nbagg

# import datamaker library
from point_n_click_classification_datamaker import Classification_Datamaker

# create an instance of the datamaker
demo = Classification_Datamaker()
# Out:
# <img src="data:image/png;base64,...">

# %%
# activate this cell to save the data you made abobve
demo.save_data(csvname = 'toy_classification_data.csv')

# %% [markdown]
# # 3.  Make your own toy regression or dimension reduction dataset
#
# The next few cells show you how to use a simple tool for creating toy regression datasets.
#
# Create an instance of the datamaker tool below, and an empty plot will appear.  Put points wherever you like by clicking on the plotting area.  Once you have finished placing points call the 'save_data' function to save your data.
#
# Note: this can be used to make datasets for both regression and dimension reduction experiments.

# %%
import sys
sys.path.append('demo_python_backend_files')
# %matplotlib nbagg

from Regression_Datamaker import Regression_Datamaker
demo = Regression_Datamaker()
# Out:
# <img src="data:image/png;base64,...">

# %%
# save the dataset you just made above
demo.save_data('toy_regression_data.csv')
